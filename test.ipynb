# %%
import sys
sys.path.append('C:/Users/Erwan/Desktop/Stage_2A/Gromov-Wasserstein/codes/gw')
import gromov
import loss
import scipy as sp
import numpy as np
import ot
import matplotlib.pyplot as pl
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# # Data definition

# %%
n=20 # nb samples

mu_s=np.array([0,0])
cov_s=np.array([[1,0],[0,1]])

mu_t=np.array([4,4,4])
cov_t=np.array([[1,0,0],[0,1,0],[0,0,1]])

xs=ot.datasets.get_2D_samples_gauss(n,mu_s,cov_s)
P=sp.linalg.sqrtm(cov_t)
xt= np.random.randn(n,3).dot(P)+mu_t

# %% [markdown]
# Distribution generation :

# %%
p=ot.unif(n)
q=ot.unif(n)
p=p.reshape(1,20)
q=q.reshape(1,20)

# %% [markdown]
# Cost matrix generation :

# %%
C1=sp.spatial.distance.cdist(xs,xs)

C2=sp.spatial.distance.cdist(xt,xt)

C1/=C1.max()
C2/=C2.max()

# %% [markdown]
# # Plot dataset

# %%
pl.subplot(121)

pl.plot(xs[:,0],xs[:,1],'+b',label='Source samples')

pl.subplot(122,projection='3d')

pl.scatter(xt[:,0],xt[:,1],xt[:,2],color='r')

pl.show()

# %% [markdown]
# # Plot cost matrices

# %%
pl.subplot(121)

pl.imshow(C1)

pl.subplot(122)

pl.imshow(C2)

pl.show()

# %% [markdown]
# # Solve Gromov-Wasserstein

# %%
gw=gromov.gromov_wasserstein(C1,C2,p,q,loss.tensor_square_loss)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-5f8fe48b9f6b> in <module>()
# ----> 1 gw=gromov.gromov_wasserstein(C1,C2,p,q,loss.tensor_square_loss)
#
# C:/Users/Erwan/Desktop/Stage_2A/Gromov-Wasserstein/codes/gw\gromov.py in gromov_wasserstein(C1, C2, p, q, L, numItermax, stopThr, verbose, log)
#      74     while (err>stopThr and cpt<numItermax):
#      75         Tprev=T
# ---> 76         tens=L(C1,C2,T,p,q)
#      77         gw=ot.bergman.sinkhorn(p,q,tens,0.1)
#      78         if (np.any(T==0)):
#
# C:/Users/Erwan/Desktop/Stage_2A/Gromov-Wasserstein/codes/gw\loss.py in tensor_square_loss(C1, C2, T, p, q)
#      73
#      74     m1=np.dot(f1(C1),p.T)
# ---> 75
#      76     c=m1.dot(indnt)+np.dot(indns.T,q).dot(f2(C2).T)
#      77
#
# ValueError: cannot reshape array of size 20 into shape (1,1)
